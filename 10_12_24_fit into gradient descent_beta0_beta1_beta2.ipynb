# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
X=np.linspace(-10,10,500)
Y=X**2-25

# %%
plt.plot(X,Y)

# %%
# Building the model
beta0 = 0
beta1 = 0
beta2 = 0
L = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = beta0+beta1*X+beta2*X**2  # The current predicted value of Y
    D_beta0 = (-2/n) * sum(Y   - Y_pred)  # Derivative wrt beta0
    D_beta1 = (-2/n) * sum(X * (Y -  Y_pred)) # Derivative wrt beta1
    D_beta2 = (-2/n) * sum(X**2 *(Y - Y_pred))# Derivative wrt beta2
    
    beta0 = beta0 - L * D_beta0  # Update beta0
    beta1 = beta1 - L * D_beta1  # Update beta1
    beta2 = beta2 - L * D_beta2  #Update beta2
    
print (beta0,beta1,beta2)
# Out:
# -2.1169523933140355 -1.8219452613266156e-16 0.620052602003399

# %%
plt.scatter(X,Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')
plt.show()

# %%
import numpy as np
p=np.linspace(0,1,100)
entropy_p=-(np.where(p>0 , p*np.log(p),0)+np.where(1-p>0,(1-p)*np.log(1-p),0))
# Out:
# C:\Users\cs\AppData\Local\Temp\ipykernel_3760\3657442636.py:3: RuntimeWarning: divide by zero encountered in log
#   entropy_p=-(np.where(p>0 , p*np.log(p),0)+np.where(1-p>0,(1-p)*np.log(1-p),0))
# C:\Users\cs\AppData\Local\Temp\ipykernel_3760\3657442636.py:3: RuntimeWarning: invalid value encountered in multiply
#   entropy_p=-(np.where(p>0 , p*np.log(p),0)+np.where(1-p>0,(1-p)*np.log(1-p),0))

# %%
plt.plot(p,entropy_p,color='blue')
plt.show()
